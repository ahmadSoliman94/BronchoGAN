# %%
# !pip install dominate

# %% [markdown]
# ### Training

# %%
# !python train.py --label_nc 0 --no_instance  --name depth2RB_phantom__without_dice --checkpoints_dir './saved_checkpoints' --model 'pix2pixHD' --batchSize 8 --dataroot './datasets/airway_dataset/' --display_winsize 156 --nThreads 14 --netG 'global' --lambda_feat 2 --n_blocks_local 1 --n_blocks_global 1  --n_local_enhancers 1 --loadSize 128  --save_epoch_freq 5
# Out:
# ------------ Options -------------
# batchSize: 8
# beta1: 0.5
# checkpoints_dir: ./saved_checkpoints
# continue_train: False
# data_type: 32
# dataroot: ./datasets/airway_dataset/
# debug: False
# display_freq: 100
# display_winsize: 156
# feat_num: 3
# fineSize: 512
# fp16: False
# gpu_ids: [0]
# input_nc: 3
# instance_feat: False
# isTrain: True
# label_feat: False
# label_nc: 0
# lambda_feat: 2.0
# loadSize: 128
# load_features: False
# load_pretrain:
# local_rank: 0
# lr: 0.0002
# max_dataset_size: inf
# model: pix2pixHD
# nThreads: 14
# n_blocks_global: 1
# n_blocks_local: 1
# n_clusters: 10
# n_downsample_E: 4
# n_downsample_global: 4
# n_layers_D: 3
# n_local_enhancers: 1
# name: depth2RB_phantom__without_dice
# ndf: 64
# nef: 16
# netG: global
# ngf: 64
# niter: 100
# niter_decay: 100
# niter_fix_global: 0
# no_flip: False
# no_ganFeat_loss: False
# no_html: False
# no_instance: True
# no_lsgan: False
# no_vgg_loss: False
# norm: instance
# num_D: 2
# output_nc: 3
# ...

# %%
# !python test.py --label_nc 0 --no_instance --model 'pix2pixHD' --name VB2RB_phantom  --checkpoints_dir './saved_checkpoints' --netG 'global'  --dataroot './datasets/airway_dataset/'  --batchSize 4 --display_winsize 156  --how_many 2267  --n_blocks_local 1 --n_blocks_global 1 --n_local_enhancers 1 --loadSize 128
# Out:
# ------------ Options -------------
# aspect_ratio: 1.0
# batchSize: 4
# checkpoints_dir: ./saved_checkpoints
# cluster_path: features_clustered_010.npy
# data_type: 32
# dataroot: ./datasets/airway_dataset/
# display_winsize: 156
# engine: None
# export_onnx: None
# feat_num: 3
# fineSize: 512
# fp16: False
# gpu_ids: [0]
# how_many: 2267
# input_nc: 3
# instance_feat: False
# isTrain: False
# label_feat: False
# label_nc: 0
# loadSize: 128
# load_features: False
# local_rank: 0
# max_dataset_size: inf
# model: pix2pixHD
# nThreads: 2
# n_blocks_global: 1
# n_blocks_local: 1
# n_clusters: 10
# n_downsample_E: 4
# n_downsample_global: 4
# n_local_enhancers: 1
# name: VB2RB_phantom
# nef: 16
# netG: global
# ngf: 64
# niter_fix_global: 0
# no_flip: False
# no_instance: True
# norm: instance
# ntest: inf
# onnx: None
# output_nc: 3
# phase: test
# resize_or_crop: scale_width
# results_dir: ./results/
# serial_batches: False
# tf_log: False
# use_dropout: False
# ...
